# %%
from maskedtensor import masked_tensor
import torch

# %%
a = torch.arange(5)
m = torch.tensor([True, True, False, False, True])
am = torch.masked.masked_tensor(a,m)

# %%
am.to_tensor(0.0)
# Out:
# tensor([0, 1, 0, 0, 4])

# %%
torch.masked.maskedtensor
# Out:
# <module 'torch.masked.maskedtensor' from '/Users/emeunier/miniforge3/envs/diffusion/lib/python3.12/site-packages/torch/masked/maskedtensor/__init__.py'>
