# %%
import torch

# %%
from __init__ import PRP

# %%
import sys

# %%
sys.path.append(PRP)
sys.path.append(PRP+'/Results/analysis_scripts/')

# %% [markdown]
# TEOS - Full

# %%
from metrics import get_density_at_surface_tensor

# %%
theta, sal = torch.meshgrid(torch.arange(0, 25, 0.1),
                            torch.arange(30, 40, 0.1), indexing='ij')

# %%
theta
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.1000,  0.1000,  0.1000,  ...,  0.1000,  0.1000,  0.1000],
#         [ 0.2000,  0.2000,  0.2000,  ...,  0.2000,  0.2000,  0.2000],
#         ...,
#         [24.7000, 24.7000, 24.7000,  ..., 24.7000, 24.7000, 24.7000],
#         [24.8000, 24.8000, 24.8000,  ..., 24.8000, 24.8000, 24.8000],
#         [24.9000, 24.9000, 24.9000,  ..., 24.9000, 24.9000, 24.9000]])

# %%
tmask = torch.ones_like(theta)

# %%
density = get_density_at_surface_tensor(theta, sal, tmask)

# %%
plt.contourf(theta, sal, density)
