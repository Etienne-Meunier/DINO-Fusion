# %%
import xarray as xr

# %%
ssh = xr.load_dataset('~/Desktop/data-dinofusion/DINO_10d_grid_T_2D.nc')
tracers = xr.load_dataset('~/Desktop/data-dinofusion/DINO_10d_grid_T_3D.nc')

# %%
ssh.isel(time_counter=200).ssh_inst.plot()

# %%
tracers
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:              (y: 199, x: 62, deptht: 36, axis_nbounds: 2,
#                           time_counter: 1800)
# Coordinates:
#     nav_lat              (y, x) float32 49kB -69.85 -69.85 ... 69.85 69.85
#     nav_lon              (y, x) float32 49kB -0.5 0.5 1.5 2.5 ... 58.5 59.5 60.5
#   * deptht               (deptht) float32 144B 5.034 15.32 ... 4.253e+03
#     time_instant         (time_counter) object 14kB 1901-01-11 00:00:00 ... 1...
#   * time_counter         (time_counter) object 14kB 1901-01-11 00:00:00 ... 1...
# Dimensions without coordinates: y, x, axis_nbounds
# Data variables:
#     deptht_bounds        (deptht, axis_nbounds) float32 288B 0.0 ... 4.506e+03
#     time_instant_bounds  (time_counter, axis_nbounds) object 29kB 1901-01-11 ...
#     time_counter_bounds  (time_counter, axis_nbounds) object 29kB 1901-01-11 ...
#     toce_inst            (time_counter, deptht, y, x) float32 3GB 0.0 ... 0.0
# ...

# %%
ssh
# Out:
# <xarray.Dataset> Size: 89MB
# Dimensions:              (y: 199, x: 62, time_counter: 1800, axis_nbounds: 2)
# Coordinates:
#     nav_lat              (y, x) float32 49kB -69.85 -69.85 ... 69.85 69.85
#     nav_lon              (y, x) float32 49kB -0.5 0.5 1.5 2.5 ... 58.5 59.5 60.5
#     time_instant         (time_counter) object 14kB 1901-01-11 00:00:00 ... 1...
#   * time_counter         (time_counter) object 14kB 1901-01-11 00:00:00 ... 1...
# Dimensions without coordinates: y, x, axis_nbounds
# Data variables:
#     time_instant_bounds  (time_counter, axis_nbounds) object 29kB 1901-01-11 ...
#     time_counter_bounds  (time_counter, axis_nbounds) object 29kB 1901-01-11 ...
#     ssh_inst             (time_counter, y, x) float32 89MB 0.0 0.0 ... 0.0 0.0
# Attributes:
#     name:         DINO_10d_grid_T_2D
#     description:  ocean T grid 2D variables 10-daily
#     title:        ocean T grid 2D variables 10-daily
#     Conventions:  CF-1.6
# ...
